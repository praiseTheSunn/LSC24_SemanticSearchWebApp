# %%
import pandas as pd

# %%
df = pd.read_csv("./metadata_v1.csv")
df.head()
# Out:
#    id               image_id  video_id  start_time  end_time
# 0   1  00001/shot00001_1_RKF         1        0.00      5.08
# 1   2  00001/shot00001_2_RKF         1        5.12      5.32
# 2   3  00001/shot00001_3_RKF         1        5.36      5.84
# 3   4  00001/shot00001_4_RKF         1        5.88      6.28
# 4   5  00001/shot00001_5_RKF         1        6.32      7.96
