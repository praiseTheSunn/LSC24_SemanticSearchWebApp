# %%
import pandas as pd

# %%
df = pd.read_csv("metadata_v2.csv")

# %%
lesson_df = df[df["video_id"].str.startswith("L25")]
cooking_df = df[df["video_id"].str.startswith("L26")]

# %%
lesson_df.to_csv("metadata_v2_lesson.csv", index=False)
cooking_df.to_csv("metadata_v2_cooking.csv", index=False)
