# %%
import os
import numpy as np
import pandas as pd

EMBEDDING_DIR = "/home/pc/LSC24_SemanticSearchWebApp/backend/data/embeddings/keyframe_clips/LHE"
COLLECTION_NAME = "vbs25_lhe_clips"
ID_MAPPING = "/home/pc/LSC24_SemanticSearchWebApp/backend/data/id_mapping/lhe/keyframes.csv"

# %%
from pymilvus import connections, utility, MilvusException, Collection
connections.connect(host="localhost", port="19530")
try:
    collections = utility.list_collections()
    print("List of collections: ", collections)
except MilvusException as e:
    print(e)


from pymilvus import MilvusClient, DataType
CLUSTER_ENDPOINT = "http://localhost:19530"
TOKEN = "root:Milvus"
client = MilvusClient(uri=CLUSTER_ENDPOINT, token=TOKEN)
# Out:
# List of collections:  ['vbs25_mvk_clips', 'vbs25_lhe_clips', 'vbs25_bgem3', 'vbs25_clips', 'vbs25_v3c_clips']

# %%
collection = Collection('vbs25_lhe_clips')
collection.num_entities
client.get_collection_stats(collection_name="vbs25_lhe_clips")
# Out:
# {'row_count': 180421}

# %%
# if not os.path.exists(ID_MAPPING):
#     df = pd.DataFrame(columns=["keyframe_name", "keyframe_id"])
#     df.to_csv(ID_MAPPING, index=False)
#     print(f"Created {ID_MAPPING}")

# %%
# id_mapping = pd.read_csv(ID_MAPPING)
# id_mapping.set_index("keyframe_name", inplace=True)
# CURR_ID = len(id_mapping)
# print("Current ID: ", CURR_ID)

# %%
import math

def get_keyframe_order_from_name(name):
    return int(name.split('.')[0])

def get_keyframe_name_from_path(path, count):
    keyframe_id = count
    context_id = math.ceil(keyframe_id / 16)
    video_id = path.split("/")[-2]
    return f"LHE/{video_id}/{context_id:05d}/{keyframe_id:05d}"

id_mapping = pd.read_csv(ID_MAPPING, index_col=0)

id_mapping_updates = []

for entry in sorted(os.scandir(EMBEDDING_DIR), key=lambda e: e.name):
    print(entry.name)
    if entry.is_dir():
        clip_name = entry.name
        clip_dir = os.path.join(EMBEDDING_DIR, clip_name)
        count = 0
        for clip_entry in sorted(os.scandir(clip_dir), key=lambda e: get_keyframe_order_from_name(e.name)):
            if clip_entry.is_file() and clip_entry.name.endswith('.npy'):
                try:
                    count += 1
                    name = clip_entry.name
                    path = os.path.join(clip_dir, name)
                    keyframe_name = get_keyframe_name_from_path(path, count)
                    keyframe_id = id_mapping.loc[keyframe_name, "keyframe_id"]
                    embedding = np.load(path).astype(np.float32)

                    # Insert data to Milvus
                    data = [{
                        "keyframe_id": id_mapping.loc[keyframe_name, "keyframe_id"],
                        "keyframe_name": keyframe_name,
                        "embedding": embedding,
                    }]
                    # collection.insert(data=data)
                    res = client.insert(collection_name=COLLECTION_NAME, data=data)
                    # print(res)
                    # print(data[0]["keyframe_name"], data[0]["keyframe_id"])

                except:
                    with open("lhe_error.log", "a") as f:
                        f.write(f"{path}\n")
                    f.close()
            else:
                print("Not a file")

        print(f"Inserted {clip_name}")
# Out:
# LHE01
# Inserted LHE01
# LHE02
# Inserted LHE02
# LHE03
# Inserted LHE03
# LHE04
# Inserted LHE04
# LHE05
# Inserted LHE05
# LHE06
# Inserted LHE06
# LHE07
# Inserted LHE07
# LHE08
# Inserted LHE08
# LHE09
# Inserted LHE09
# LHE10
# Inserted LHE10
# LHE11
# Inserted LHE11
# LHE12
# Inserted LHE12
# LHE13
# Inserted LHE13
# LHE14
# Inserted LHE14
# LHE15
# Inserted LHE15
# LHE16
# Inserted LHE16
# LHE17
# Inserted LHE17
# LHE18
# Inserted LHE18
# LHE19
# Inserted LHE19
# LHE20
# Inserted LHE20
# LHE21
# Inserted LHE21
# LHE22
# Inserted LHE22
# LHE23
# Inserted LHE23
# LHE24
# Inserted LHE24
# LHE25
# Inserted LHE25
# LHE26
# Inserted LHE26
# LHE27
# Inserted LHE27
# LHE28
# Inserted LHE28
# LHE29
# Inserted LHE29
# LHE30
# Inserted LHE30
# LHE31
# Inserted LHE31
# LHE32
# Inserted LHE32
# LHE33
# Inserted LHE33
# LHE34
# Inserted LHE34
# LHE35
# Inserted LHE35
# LHE36
# Inserted LHE36
# LHE37
# Inserted LHE37
# LHE38
# Inserted LHE38
# LHE39
# Inserted LHE39
# LHE40
# Inserted LHE40
# LHE41
# Inserted LHE41
# LHE42
# Inserted LHE42
# LHE43
# Inserted LHE43
# LHE44
# Inserted LHE44
# LHE45
# Inserted LHE45
# LHE46
# Inserted LHE46
# LHE47
# Inserted LHE47
# LHE48
# Inserted LHE48
# LHE49
# Inserted LHE49
# LHE50
# Inserted LHE50
# LHE51
# Inserted LHE51
# LHE52
# Inserted LHE52
# LHE53
# Inserted LHE53
# LHE54
# Inserted LHE54
# LHE55
# Inserted LHE55
# LHE56
# Inserted LHE56
# LHE57
# Inserted LHE57
# LHE58
# Inserted LHE58
# LHE59
# Inserted LHE59
# LHE60
# Inserted LHE60
# LHE61
# Inserted LHE61
# LHE62
# Inserted LHE62
# LHE63
# Inserted LHE63
# LHE64
# Inserted LHE64
# LHE65
# Inserted LHE65
# LHE66
# Inserted LHE66
# LHE67
# Inserted LHE67
# LHE68
# Inserted LHE68
# LHE69
# Inserted LHE69
# LHE70
# Inserted LHE70
# LHE71
# Inserted LHE71
# LHE72
# Inserted LHE72
# LHE73
# Inserted LHE73
# LHE74
# Inserted LHE74
# LHE75
# Inserted LHE75

# %%
# client.get(collection_name="vbs25_clips", ids=[1, 2, 3])[0]['embedding'].__len__()
client.get(collection_name="vbs25_lhe_clips", ids=[3125])
# Out:
# data: ["{'keyframe_id': 3125, 'keyframe_name': 'LHE/LHE01/00196/03125', 'embedding': [0.029521368, -0.03847474, 0.015389896, -0.022837285, 0.024467045, 0.009154513, 0.0009006235, -0.0016813357, -0.005533967, -0.017494144, -0.014430606, -0.0003916455, -0.008912111, -0.009577425, -0.0149979275, 0.008607821, -0.0009051363, 0.040558357, 0.029665777, 0.0062405406, 0.01917548, -0.014482181, 0.018711308, -0.022630986, 0.015493045, -0.01713312, -0.00029768283, -0.006756288, 0.011439272, -0.47333214, 0.016256351, -0.005992982, -0.0048867045, -0.0035406044, -0.022651616, 0.09778567, 0.014461551, -0.059125256, -0.008540773, 0.022404058, -0.021743901, -0.024178227, -0.040826548, 0.02737586, 0.024095709, 0.0130071435, -0.016803043, -0.0043658, 0.022878544, -0.011191714, 0.0048428657, 0.0072875074, 0.025292242, -0.014956668, -0.0021945043, 0.029913336, 0.004043458, 0.003200211, 0.035999153, 0.007566011, -0.03459632, -0.007978609, -0.016638003, 0.017865483, 